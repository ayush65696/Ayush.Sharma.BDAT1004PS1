# %% [markdown]
# # BDAT 1004 - Data Programming
# PROBLEM SET 1
# >>>Student Number - 200465696

# %% [markdown]
# ## Question 1 C#
#    What Data type is each of the following?
#
#
#    Expression          | DataType
#      :---------------- | -----------------:
#      5                 | Integer Type
#      5.0               | Float type
#      5 > 1             | Boolean data type
#      '5'               | Integer data type
#      5*2               | Integer data type
#      '5' * 2           | Integer data type
#      '5' + '2'         | Integer data type
#      5/2               | Float data type
#      5//2              | Float data type
#      [5,2,1]           | Integer data type
#      5 in [1,4,2]      | Boolean data type
#      Pi                | Float data type, decimal

# %% [markdown]
# ## Question 2
# Write (and evaluate) C# expressions that answer these questions:
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# c. Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %%
#a. How many letters are there in 'Supercalifragilisticexpialidocious'?
using System; #Visual Studio syntax
namespace Problem_Set_1
{
    class Program
    {
        static void Main(string[] args)
        {
            string word = "Supercalifragilisticexpialidocious";
            Console.WriteLine("Length of the given word is : " + word.Length);
        }
    }
}

# %% [markdown]
# ![Q2_a.png](attachment:Q2_a.png)

# %%
#b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
using System;

namespace Problem_Set_1
{
    class Program
    {
        static void Main(string[] args)
        {
            string word = "Supercalifragilisticexpialidocious";
            if (word.Contains("ice"))
            {
                Console.WriteLine("ice is a substring of " + word);
            }

        }
    }
}

# %% [markdown]
# ![Q2_b.png](attachment:Q2_b.png)

# %%
#c. Which of the following words is the longest:Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or Bababadalgharaghtakamminarronnkonn?
using System;

namespace Problem_Set_1
{
    class Program
    {
        static void Main(string[] args)
        {
            string[] words = { "Supercalifragilisticexpialidocious", "Honorificabilitudinitatibus", "Bababadalgharaghtakamminarronnkonn" };
            string longest = "";
            int temp = 0; #int variable created for comparing word length and storing in empty string longest from for loop
            foreach (string item in words)
            {
                if (item.Length > temp)
                {
                    temp = item.Length;
                    longest = item;
                }
            }

            Console.WriteLine("The longest word: {0}", longest); #{0}: returning only value in the string longest
        }
    }
}

# %% [markdown]
# ![Q2.c.png](attachment:Q2.c.png)

# %%
#d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian','Bartok', 'Bellini', 
#'Buxtehude', 'Bernstein'. Which one comes last?
using System;//Visual Studio Syntax

namespace Problem_Set_1
{
    class Program
    {
        static void Main(string[] args)
        {
            string[] dictionary = { "Berlioz", "Borodin", "Brian", "Bartok", "Bellini", "Buxtehude", "Bernstein" };
            Array.Sort(dictionary);
            Console.WriteLine("Word that comes first in the dictionary: " + dictionary[0]);
            Console.WriteLine("Word that comes last in the dictionary: " + dictionary[6]);
        }
    }
}

# %% [markdown]
# ![Q2.d.png](attachment:Q2.d.png)

# %% [markdown]
# ## Question 3 C#
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is s(s - a)(s -b)(s - c), where
# s = (a +b +c)/2.
# triangleArea(2,2,2)
# 1.7320508075688772

# %%
using System;

namespace Problem_Set_1
{
    class Program
    {
        public static void Main(string[] args)
        {
            double a, b, c;

            Console.WriteLine("Enter side a: ");
            a = Convert.ToDouble(Console.ReadLine());
            Console.WriteLine("Enter side b: ");
            b = Convert.ToDouble(Console.ReadLine());
            Console.WriteLine("Enter side c: ");
            c = Convert.ToDouble(Console.ReadLine());

            double area = Program.TriangleArea(a, b, c);
            Console.WriteLine(area);
            Console.ReadLine();


        }
        public static double TriangleArea(double a, double b, double c)
        {
            double s = (a + b + c) / 2;
            return Math.Sqrt(s * (s - a) * (s - b) * (s - c));
        }
    }
}

# %% [markdown]
# ![Q3.png](attachment:Q3.png)

# %% [markdown]
# ## Question 4 C#
# Write a program in C# Sharp to separate odd and even integers in separate arrays.
# Go to the editor
# Test Data :
# Input the number of elements to be stored in the array :5
# Input 5 elements in the array :
# element - 0 : 25
# element - 1 : 47
# element - 2 : 42
# element - 3 : 56
# element - 4 : 32
# Expected Output:
# The Even elements are:
# 42 56 32
# The Odd elements are :
# 25 47

# %%
using System;

namespace Problem_Set_1
{
    class Program
    {
        public static void Main(string[] args)
        {
            int[] arr = new int[]
                {25,42,47,52,56};
            int[] arr2 = new int[5];
            int[] arr3 = new int[5];
            int i, j = 0, k = 0;
            for (i = 0; i < 5; i++)
            {
                if (arr[i] % 2 == 0)
                {
                    arr2[j] = arr[i];
                    j++;
                }
                else
                {
                    arr3[k] = arr[i];
                    k++;
                }
            }
            Console.WriteLine("The Even Elements are:");
            for (i = 0; i < j; i++)
            {
                Console.WriteLine(arr2[i]);
            }
            Console.WriteLine("The Odd Elements are:");
            for (i = 0; i < k; i++)
            {
                Console.WriteLine(arr3[i]);
            }
        }
    }
}

# %% [markdown]
# ![Q4.png](attachment:Q4.png)

# %% [markdown]
# ## Question 5 C#
# >>>a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
# depending on whether the point (x,y) lies in the rectangle with lower left
# corner (x1,y1) and upper right corner (x2,y2).
# -inside(1,1,0,0,2,3)
# True
# -inside(-1,-1,0,0,2,3)
# False
# >>>b. Use function inside() from part a. to write an expression that tests whether
# the point (1,1) lies in both of the following rectangles: one with lower left
# corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
# left corner (0.5, 0.2) and upper right corner (1.1, 2)

# %%
#a. part
using System;

namespace Problem_Set_1
{
    class Program
    {
        public static void Main(string[] args)
        {
            int x = -1, y = -1;//True for (1,1)
            int x1 = 0, y1 = 0,
                x2 = 2, y2 = 3; 
 
            if (inside(x, y, x1, y1, x2, y2))
                Console.WriteLine("True");
            else
                Console.WriteLine("False");
        }
        static bool inside(int x, int y, int x1,
                              int y1, int x2, int y2)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
                return true;
            return false;
        }
    }
}

# %% [markdown]
# ![Q5a1.png](attachment:Q5a1.png)

# %% [markdown]
# ![Q5a2.png](attachment:Q5a2.png)

# %%
# b. part
using System;

namespace Problem_Set_1
{
    class Program
    {
        public static void Main(string[] args)
        {
            int x = 1, y = 1;
            double x1 = 0.3, x2 = 1.1, y1 = 0.5, y2 = 0.7;
            if (inside(x, y, x1, y1, x2, y2))
                Console.WriteLine("True");
            else
                Console.WriteLine("False");
        }
        static bool inside(int x, int y, double x1,
                              double y1, double x2, double y2)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
                return true;
            return false;
        }
    }
}

o/p False

using System;

namespace Problem_Set_1
{
    class Program
    {
        public static void Main(string[] args)
        {
            int x = 1, y = 1;
            double x1 = 0.5, x2 = 1.1, y1 = 0.2, y2 = 2;
            if (inside(x, y, x1, y1, x2, y2))
                Console.WriteLine("True");
            else
                Console.WriteLine("False");
        }
        static bool inside(int x, int y, double x1,
                              double y1, double x2, double y2)
        {
            if (x > x1 && x < x2 && y > y1 && y < y2)
                return true;
            return false;
        }
    }
}

o/p True

# %% [markdown]
# ## Question 6 Python
# You can turn a word into pig-Latin using the following two rules (simplified):
# • If the word starts with a consonant, move that letter to the end and append
# 'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
# • If the word starts with a vowel, simply append 'way' to the end of the word.
# For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . For
# our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
# >Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case
# characters. Your output should always be lower case however.
# -pig('happy')
# 'appyhay'
# -pig('Enter')
# 'enterway'

# %%
pigLatin = input("Enter word:")
vowels = ['a','e','i','o','u','A','E','I','O','U']
def pig(pigLatin): 
    alpha = pigLatin[0]
    if alpha in vowels: 
         pigLatin = pigLatin.lower()
         pigLatin = pigLatin + "way" 
         return pigLatin
    elif alpha not in vowels:
        pigLatin = pigLatin[1:] +alpha+ "ay" 
        pigLatin = pigLatin.lower()
        return pigLatin 

print(pig(pigLatin))
# Out:
# Enter word:Enter
# enterway

# %% [markdown]
# ## Question 7
# File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.
# Write a function bldcount() that reads the file with name name and reports (i.e.,
# prints) how many patients there are in each bloodtype.
# bldcount('bloodtype.txt')
# >>There are 10 patients of blood type A.
#   There is one patient of blood type B.
#   There are 10 patients of blood type AB.
#   There are 12 patients of blood type O.
#   There are no patients of blood type OO

# %%
def bldcount(): 
    infile = open('bloodtype1.txt','r')
    content = infile.readline()
    infile.close()
    wordList = content.split()
    print("There are " + str(wordList.count('A'))+" patients of blood type A.")
    print("There are " + str(wordList.count('B'))+" patients of blood type B.")
    print("There are " + str(wordList.count('AB'))+" patients of blood type AB.")
    print("There are " + str(wordList.count('O'))+" patients of blood type O.")
    print("There are " + str(wordList.count('OO'))+" patients of blood type OO.")
    
bldcount()
# Out:
# There are 15 patients of blood type A.
# There are 1 patients of blood type B.
# There are 13 patients of blood type AB.
# There are 15 patients of blood type O.
# There are 0 patients of blood type OO.

# %% [markdown]
# ## Question 8 Python
# Write a function curconv() that takes as input:
# 1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
# 'EUR' for the Euro)
# 2. an amount
# and then converts and returns the amount in US dollars.
#
# curconv('EUR', 100)
# 122.96544
#
# curconv('JPY', 100)
# 1.241401

# %%
def curconv(Curr, Amt):
    infile = open('currencies.txt','r')
    content = infile.readlines()
    tempDict = {}
    for line in content:
        splitLine = line.split()
        tempDict[splitLine[0]] = float(splitLine[1]) #separate key and values assigned in dictionary
    result = tempDict[Curr] * Amt
    return result
    infile.close()

curconv('SEK',100)
# Out:
# 14.826900000000002

# %% [markdown]
# ## Question 9 Python
# Each of the following will cause an exception (an error). Identify what type of
# exception each will cause.
# Trying to add incompatible variables, as in
# adding 6 + ‘a’
# Referring to the 12th item of a list that has only 10
# items
# Using a value that is out of range for a function’s
# input, such as calling math.sqrt(-1.0)
# Using an undeclared variable, such as print(x)
# when x has not been defined
# Trying to open a file that does not exist, such as
# mistyping the file name or looking in the wrong
# directory

# %%
#1.
y=3
print(y + 'a') 
#This is a Type error Raised when an operation of function is applied to an object of the wrong type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-1cbbdeb4cf25> in <module>
#       1 #1.
#       2 y=3
# ----> 3 print(y + 'a')
#       4 #This is a Type error Raised when an operation of function is applied to an object of the wrong type
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#2.
list=['ABC','cvB', 'DFS','AA',11,34,44,'vc','python', 'JSON']
print(list[11])
#This is an Index Error Raised when a sequence index is outside the range of valid indexes
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-136-a90c90d6cd07> in <module>
#       1 #2.
#       2 list=['ABC','cvB', 'DFS','AA',11,34,44,'vc','python', 'JSON']
# ----> 3 print(list[11])
#
# IndexError: list index out of range

# %%
#3.
import math
def out(a):
    res = math.sqrt(a);
    return res
out(-1)
#This is a Value Error Raised when operation or function has an argument of the right type but incorrect value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-7119ee893ade> in <module>
#       4     res = math.sqrt(a);
#       5     return res
# ----> 6 out(-1)
#       7 #This is a Value Error Raised when operation or function has an argument of the right type but incorrect value
#
# <ipython-input-145-7119ee893ade> in out(a)
#       2 import math
#       3 def out(a):
# ----> 4     res = math.sqrt(a);
#       5     return res
#       6 out(-1)
#
# ValueError: math domain error

# %%
#4.
print(a)
#This is a Name Error Raised when attempting to evaluate an unassigned identifier (name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-c8b26f3c90ea> in <module>
#       1 #4.
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
infile = open('bloodtype.txt','r')
infile.read(1)
#This is FileNotFound error when no file or directory is found
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-152-de2de5165ace> in <module>
# ----> 1 infile = open('bloodtype.txt','r')
#       2 infile.read(1)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bloodtype.txt'

# %% [markdown]
# ## Question 10 Python
# Encryption is the process of hiding the meaning of a text by substituting letters in the
# message with other letters, according to some system. If the process is successful, no
# one but the intended recipient can understand the encrypted message. Cryptanalysis
# refers to attempts to undo the encryption, even if some details of the encryption are
# unknown (for example, if an encrypted message has been intercepted). The first step
# of cryptanalysis is often to build up a table of letter frequencies in the encrypted text.
# Assume that the string letters is already defined as
# 'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()
# that takes a string as its only parameter, and returns a list of integers, showing the
# number of times each character appears in the text. Your function may ignore any
# characters that are not in letters.
#  frequencies('The quick red fox got bored and went home.')
# [1, 1, 1, 3, 5, 1, 1, 2, 1, 0, 1, 0, 1, 2, 4, 0, 1, 2, 0, 2,
# 1, 0, 1, 1, 0, 0]
#  frequencies('apple')

# %%
def frequencies(letters):
    
#unable to do
